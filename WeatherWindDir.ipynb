# %%
weather = '/home/vant/Escritorio/MasterDataScience/Clases/Python/weather_year.csv'

# %%
# %%time 

# !cat {weather} |wc -l
# Out:
# 367
# CPU times: user 5.38 ms, sys: 199 µs, total: 5.58 ms
# Wall time: 107 ms

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# /home/vant/anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
pd.options.display.max_columns=None

dfw = pd.read_csv(weather)
dfw.head()
# Out:
#          EDT  Max TemperatureF  Mean TemperatureF  Min TemperatureF  \
# 0  2012-3-10                56                 40                24
# 1  2012-3-11                67                 49                30
# 2  2012-3-12                71                 62                53
# 3  2012-3-13                76                 63                50
# 4  2012-3-14                80                 62                44
#
#    Max Dew PointF  MeanDew PointF  Min DewpointF  Max Humidity  \
# 0              24              20             16            74
# 1              43              31             24            78
# 2              59              55             43            90
# 3              57              53             47            93
# 4              58              52             43            93
#
#     Mean Humidity   Min Humidity   Max Sea Level PressureIn  \
# 0              50             26                      30.53
# ...

# %%
dfw.shape
#366 dias en 366 lineas, y 23 columnas de informacion
# Out:
# (366, 23)

# %%
dfw.count()
#una forma sencilla de buscar NaN es comprobar los datos que dispone cada columna
# Out:
# EDT                           366
# Max TemperatureF              366
# Mean TemperatureF             366
# Min TemperatureF              366
# Max Dew PointF                366
# MeanDew PointF                366
# Min DewpointF                 366
# Max Humidity                  366
#  Mean Humidity                366
#  Min Humidity                 366
#  Max Sea Level PressureIn     366
#  Mean Sea Level PressureIn    366
#  Min Sea Level PressureIn     366
#  Max VisibilityMiles          366
#  Mean VisibilityMiles         366
#  Min VisibilityMiles          366
#  Max Wind SpeedMPH            366
#  Mean Wind SpeedMPH           366
#  Max Gust SpeedMPH            365
# PrecipitationIn               366
#  CloudCover                   366
#  Events                       162
#  WindDirDegrees               366
# dtype: int64

# %%
dfw.dtypes
#datos alfanumericos (Float and Integer) en su mayoria
# Out:
# EDT                            object
# Max TemperatureF                int64
# Mean TemperatureF               int64
# Min TemperatureF                int64
# Max Dew PointF                  int64
# MeanDew PointF                  int64
# Min DewpointF                   int64
# Max Humidity                    int64
#  Mean Humidity                  int64
#  Min Humidity                   int64
#  Max Sea Level PressureIn     float64
#  Mean Sea Level PressureIn    float64
#  Min Sea Level PressureIn     float64
#  Max VisibilityMiles            int64
#  Mean VisibilityMiles           int64
#  Min VisibilityMiles            int64
#  Max Wind SpeedMPH              int64
#  Mean Wind SpeedMPH             int64
#  Max Gust SpeedMPH            float64
# PrecipitationIn                object
#  CloudCover                     int64
#  Events                        object
#  WindDirDegrees                 int64
# dtype: object

# %%
#seleccionemos las columnas que vamos a utilizar esta vez

# %%
dfw1 = dfw[['EDT', ' Events', ' WindDirDegrees']]
dfw1.head()
# Out:
#          EDT  Events   WindDirDegrees
# 0  2012-3-10     NaN              138
# 1  2012-3-11    Rain              163
# 2  2012-3-12    Rain              190
# 3  2012-3-13     NaN              242
# 4  2012-3-14     NaN              202

# %%
f, ax = plt.subplots(figsize=(12,8))
dfw1.plot(ax=ax)

# %%
import seaborn as sns

sns.distplot(dfw1[' WindDirDegrees'])
# Out:
# /home/vant/anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /home/vant/anaconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /home/vant/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.jointplot(data=dfw, x=' WindDirDegrees', y='Mean TemperatureF')
# Out:
# /home/vant/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# /home/vant/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.jointplot(data=dfw, x=' WindDirDegrees', y='Mean TemperatureF', kind='kde')

# %%
sns.boxplot(data=dfw1, y=' WindDirDegrees', x='EDT')
